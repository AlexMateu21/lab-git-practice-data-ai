# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Àlex Mateu Cerezuela"
reason = "Data analytics looks like the perfect upgrage to my background in Business Administration, allowing me to turn data into better business decisions"
fun_fact ="I have been analysing data for fun since I was a kid thanks to a strategy card game I used to play competitively, where understanding probabilities, statistics and trends is key. Now I'm excited to turn that analytical mindset into a professional skill set and built a future in data"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Àlex Mateu Cerezuela. I’m excited to learn because Data analytics looks like the perfect upgrage to my background in Business Administration, allowing me to turn data into better business decisions. A fun fact about me is: I have been analysing data for fun since I was a kid thanks to a strategy card game I used to play competitively, where understanding probabilities, statistics and trends is key. Now I'm excited to turn that analytical mindset into a professional skill set and built a future in data.
